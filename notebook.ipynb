# %%
from dmak.examples import supertree_prob_sensitivity_chp3 as data
from dmak.decisiontree import DecisionTree
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

tree = DecisionTree(
    variables = data(),
    initial_variable="bid",
    utility="exp",
    risk_tolerance=100,
    display='ce',
)
tree.evaluate()
tree.rollback()
# tree.display(max_deep=1)
tree.risk_attitude_sensitivity('exp', 75)
# plt.ylim(0, 75)

# tree.nodes()
#tree.evaluate()
#tree.rollback()
# tree.nodes()
# tree.risk_profile(0, cumulative=True, single=False)

# %%
import matplotlib.pyplot as plt

values = [-100,    0,  100,   300, 300]
probs =  [   0, 0.15,  0.5,  0.85,   1]
plt.step(values, probs)
plt.show()

# %%
import json
json.dumps({'4': 5, '6': 7}, sort_keys=True, indent=4)
# Out:
# '{\n    "4": 5,\n    "6": 7\n}'
